# %% [markdown]
# # 6. Packaging and Shipping Code
#
# Links: [Video](https://www.youtube.com/watch?v=KBMiB-8P4Ns&list=PLyzOVJj3bHQunmnnTXrNbZnBaCA-ieK4L&index=6) | [Text](https://missing.csail.mit.edu/2026/shipping-code/)
#
# Resources:
# - Follow the lecture page's inline references for deeper reading on the tools mentioned below.
#
# Note: Install `bash_kernel` and run `python -m bash_kernel.install --sys-prefix` (restart VS Code needed) for Jupyter notebooks to run bash code cells.
#
# This notebook mirrors `1-course-shell/main.ipynb` as an exercise workbook. The prompts are copied
# from the lecture page and the code cells are intentionally left open for your own notes,
# experiments, and solutions.

# %% [markdown]
# ##### 1. Save your environment with `printenv` to a file, create a venv, activate it, `printenv` to another file and `diff before.txt after.txt`. What changed in the environment? Why does the shell prefer the venv?
#
# Hint: look at `$PATH` before and after activation. Run `which deactivate` and
# reason about what the deactivate bash function is doing.

# %%
# Work here.

# %% [markdown]
# ##### 2. Create a Python package with a `pyproject.toml` and install it in a virtual environment. Create a lockfile and inspect it.

# %%
# Work here.

# %% [markdown]
# ##### 3. Install Docker and use it to build the Missing Semester class website locally using docker compose.

# %%
# Work here.

# %% [markdown]
# ##### 4. Write a Dockerfile for a simple Python application. Then write a `docker-compose.yml` that runs your application alongside a Redis cache.

# %%
# Work here.

# %% [markdown]
# ##### 5. Publish a Python package to TestPyPI (don't publish to the real PyPI unless it's worth sharing). Then build a Docker image with said package and push it to `ghcr.io`.

# %%
# Work here.

# %% [markdown]
# ##### 6. Make a website using GitHub Pages. Extra (non-)credit: configure it with a custom domain.

# %%
# Work here.
